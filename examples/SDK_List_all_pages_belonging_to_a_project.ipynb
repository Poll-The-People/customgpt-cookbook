# %%
# !pip install customgpt-client==1.1.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting customgpt-client==1.1.2
#   Downloading customgpt_client-1.1.2-py3-none-any.whl (304 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 304.7/304.7 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=21.3.0 in /usr/local/lib/python3.10/dist-packages (from customgpt-client==1.1.2) (23.1.0)
# Collecting httpx<0.25.0,>=0.15.4 (from customgpt-client==1.1.2)
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 9.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from customgpt-client==1.1.2) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.25.0,>=0.15.4->customgpt-client==1.1.2) (2023.5.7)
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx<0.25.0,>=0.15.4->customgpt-client==1.1.2)
#   Downloading httpcore-0.17.2-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<0.25.0,>=0.15.4->customgpt-client==1.1.2) (3.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.25.0,>=0.15.4->customgpt-client==1.1.2) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.8.0->customgpt-client==1.1.2) (1.16.0)
# Collecting h11<0.15,>=0.13 (from httpcore<0.18.0,>=0.15.0->httpx<0.25.0,>=0.15.4->customgpt-client==1.1.2)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx<0.25.0,>=0.15.4->customgpt-client==1.1.2) (3.7.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->httpcore<0.18.0,>=0.15.0->httpx<0.25.0,>=0.15.4->customgpt-client==1.1.2) (1.1.1)
# Installing collected packages: h11, httpcore, httpx, customgpt-client
# Successfully installed customgpt-client-1.1.2 h11-0.14.0 httpcore-0.17.2 httpx-0.24.1

# %% [markdown]
# **Create your custom chat bot using a sitemap.**

# %%
from customgpt_client import CustomGPT
CustomGPT.api_key = "YOUR_API_TOKEN"

# %% [markdown]
# **An example for to create a project with a sitemap**

# %%
# Give a name to your project
project_name = 'Example ChatBot using Sitemap'
sitemap_path = 'https://adorosario.github.io/small-sitemap.xml'

create_project = CustomGPT.Project.create(project_name=project_name, sitemap_path=sitemap_path)
print(create_project)
# Out:
# Response(status_code=<HTTPStatus.CREATED: 201>, content=b'{"data":{"id":582,"project_name":"Example ChatBot using Sitemap","sitemap_path":null,"user_id":35,"is_chat_active":null,"created_at":"2023-06-27T15:35:04.000000Z","updated_at":"2023-06-27T15:35:04.000000Z","is_shared":null,"deleted_at":null,"type":"SITEMAP"},"status":"success"}', headers=Headers({'server': 'nginx', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'cache-control': 'no-cache, private', 'date': 'Tue, 27 Jun 2023 15:35:04 GMT', 'x-ratelimit-limit': '60', 'x-ratelimit-remaining': '58', 'access-control-allow-origin': '*', 'x-xss-protection': '1; mode=block', 'x-content-type-options': 'nosniff'}), parsed=CreateProjectResponse201(status=<CreateProjectResponse201Status.SUCCESS: 'success'>, data=CreateProjectResponse201Data(id=582, project_name='Example ChatBot using Sitemap', sitemap_path=None, is_chat_active=None, user_id=35, created_at=datetime.datetime(2023, 6, 27, 15, 35, 4, tzinfo=tzutc()), updated_at=datetime.datetime(2023, 6, 27, 15, 35, 4, tzinfo=tzutc()), deleted_at=None, type=<CreateProjectResponse201DataType.SITEMAP: 'SITEMAP'>, is_shared=None, shareable_slug=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, shareable_link=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, embed_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, live_chat_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, additional_properties={}), additional_properties={}))

# %% [markdown]
# **Add conversation to fill in pages**

# %%
project_id = create_project.parsed.data.id
# to make the chatbot sharable we will set is_shared to 1
project_conversation = CustomGPT.Conversation.create(project_id=project_id, name='conversation')
print(project_conversation)
# Out:
# Response(status_code=<HTTPStatus.CREATED: 201>, content=b'{"data":{"project_id":582,"name":"conversation","created_by":35,"session_id":"b8b09d81-9e54-42a8-95ae-3e0c225c2ace","updated_at":"2023-06-27T15:35:07.000000Z","created_at":"2023-06-27T15:35:07.000000Z","id":243},"status":"success"}', headers=Headers({'server': 'nginx', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'cache-control': 'no-cache, private', 'date': 'Tue, 27 Jun 2023 15:35:07 GMT', 'x-ratelimit-limit': '60', 'x-ratelimit-remaining': '57', 'access-control-allow-origin': '*', 'x-xss-protection': '1; mode=block', 'x-content-type-options': 'nosniff'}), parsed=CreateProjectConversationResponse201(status=<CreateProjectConversationResponse201Status.SUCCESS: 'success'>, data=CreateProjectConversationResponse201Data(created_at=datetime.datetime(2023, 6, 27, 15, 35, 7, tzinfo=tzutc()), updated_at=datetime.datetime(2023, 6, 27, 15, 35, 7, tzinfo=tzutc()), deleted_at=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, id=243, name='conversation', project_id=582, created_by=35, session_id='b8b09d81-9e54-42a8-95ae-3e0c225c2ace', additional_properties={}), additional_properties={}))

# %% [markdown]
# **Get Project Page**

# %%
project_pages = CustomGPT.Page.get(project_id=project_id)
print(project_pages)
total = project_pages.parsed.data.pages.total
for i in range(total):
  page_num = i +1
  page = CustomGPT.Page.get(project_id=project_id, page=page_num)
  print(page)
# Out:
# Response(status_code=<HTTPStatus.OK: 200>, content=b'{"data":{"project":{"id":582,"project_name":"Example ChatBot using Sitemap","sitemap_path":null,"user_id":35,"is_chat_active":1,"created_at":"2023-06-27T15:35:04.000000Z","updated_at":"2023-06-27T15:35:18.000000Z","is_shared":0,"deleted_at":null,"type":"SITEMAP"},"pages":{"current_page":1,"data":[{"id":12619,"page_url":"https:\\/\\/apnews.com\\/article\\/tom-brady-tampa-bay-buccaneers-new-england-patriots-indianapolis-colts-denver-broncos-64c660906bfdd828c9cf69e94cfefcb7","page_url_hash":"c63e5fb2e92bd5345c91f8d50b5b3736","created_at":"2023-06-27T15:35:05.000000Z","updated_at":"2023-06-27 15:35:31","crawl_status":"ok","index_status":"ok","is_file":false},{"id":12618,"page_url":"https:\\/\\/apnews.com\\/article\\/tom-brady-retirement-a53ee71d6ab99276fd0765052c0dd7aa","page_url_hash":"13d0ae8867ab1f7177464f48efaf28e2","created_at":"2023-06-27T15:35:05.000000Z","updated_at":"2023-06-27 15:35
created_at":"2023-06-27T15:35:05.000000Z","updated_at":"2023-06-27 15:35:23","crawl_status":"ok","index_status":"ok","is_file":false},{"id":12612,"page_url":"https:\\/\\/985thesportshub.com\\/listicle\\/tom-brady-retiring-from-football-after-22-seasons-7-super-bowl-titles\\/","page_url_hash":"ced794a09f3d91825453d9d141e75794","created_at":"2023-06-27T15:35:05.000000Z","updated_at":"2023-06-27 15:36:18","crawl_status":"ok","index_status":"ok","is_file":false},{"id":12611,"page_url":"https:\\/\\/247sports.com\\/player\\/tom-brady-76179\\/","page_url_hash":"b18a144a7b5de4a94cc57c64346ccf2f","created_at":"2023-06-27T15:35:05.000000Z","updated_at":"2023-06-27 15:35:45","crawl_status":"ok","index_status":"ok","is_file":false},{"id":12610,"page_url":"https:\\/\\/1033thegoat.com\\/tom-brady-has-won-more-super-bowls-than-these-18-teams-combined\\/","page_url_hash":"4d05356e44f08caf9bda3a7667d4f1aa","created_at":"2023-06-27T15:35:05.000000Z","updated_at":"2023-06-27 15:35:28","crawl_status":"ok","index_status":"ok","is_file":false}],"first_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","from":1,"last_page":1,"last_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","next_page_url":null,"path":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages","per_page":20,"prev_page_url":null,"to":10,"total":10}},"status":"success"}', headers=Headers({'server': 'nginx', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'vary': 'Accept-Encoding', 'cache-con ...
# Response(status_code=<HTTPStatus.OK: 200>, content=b'{"data":{"project":{"id":582,"project_name":"Example ChatBot using Sitemap","sitemap_path":null,"user_id":35,"is_chat_active":1,"created_at":"2023-06-27T15:35:04.000000Z","updated_at":"2023-06-27T15:35:18.000000Z","is_shared":0,"deleted_at":null,"type":"SITEMAP"},"pages":{"current_page":2,"data":[],"first_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","from":null,"last_page":1,"last_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","next_page_url":null,"path":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages","per_page":20,"prev_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","to":null,"total":10}},"status":"success"}', headers=Headers({'server': 'nginx', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'vary': 'Accept-Encoding', 'cache-control': 'no-cache, private', 'date': 'Tue, 27 Jun 2023 15:42:50 GMT', 'x-ratelimit-limit': '60', 'x-ratelimit-remaining': '56', 'access-control-allow-origin': '*', 'x-xss-protection': '1; mode=block', 'x-content-type-options': 'nosniff', 'content-encoding': 'gzip'}), parsed=GetProjectPagesResponse200(status=<GetProjectPagesResponse200Status.SUCCESS: 'success'>, data=GetProjectPagesResponse200Data(project=GetProjectPagesResponse200DataProject(id=582, project_name='Example ChatBot using Sitemap', sitemap_path=None, is_chat_active=1, user_id=35, created_at=datetime.datetime(2023, 6, 27, 15, 35, 4, tzinfo=tzutc()), updated_at=datetime.datetime(2023, 6, 27, 15, 35, 18, tzinfo=tzutc()), deleted_at=None, type=<GetProjectPagesResponse200DataProjectType.SITEMAP: 'SITEMAP'>, is_shared=0, shareable_slug=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, shareable_link=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, embed_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, live_chat_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, additional_properties={}), pages=GetProjectPagesResponse200DataPages(current_page=2, data=[], first_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', from_=None, last_page=1, last_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', links=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, next_page_url=None, path='https://dev.customgpt.ai/api/v1/projects/582/pages', per_page=20, prev_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', to=None, total=10, additional_properties={}), additional_properties={}), additional_properties={}))
# Response(status_code=<HTTPStatus.OK: 200>, content=b'{"data":{"project":{"id":582,"project_name":"Example ChatBot using Sitemap","sitemap_path":null,"user_id":35,"is_chat_active":1,"created_at":"2023-06-27T15:35:04.000000Z","updated_at":"2023-06-27T15:35:18.000000Z","is_shared":0,"deleted_at":null,"type":"SITEMAP"},"pages":{"current_page":3,"data":[],"first_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","from":null,"last_page":1,"last_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","next_page_url":null,"path":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages","per_page":20,"prev_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=2&duration=90&order=desc","to":null,"total":10}},"status":"success"}', headers=Headers({'server': 'nginx', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'vary': 'Accept-Encoding', 'cache-control': 'no-cache, private', 'date': 'Tue, 27 Jun 2023 15:42:51 GMT', 'x-ratelimit-limit': '60', 'x-ratelimit-remaining': '55', 'access-control-allow-origin': '*', 'x-xss-protection': '1; mode=block', 'x-content-type-options': 'nosniff', 'content-encoding': 'gzip'}), parsed=GetProjectPagesResponse200(status=<GetProjectPagesResponse200Status.SUCCESS: 'success'>, data=GetProjectPagesResponse200Data(project=GetProjectPagesResponse200DataProject(id=582, project_name='Example ChatBot using Sitemap', sitemap_path=None, is_chat_active=1, user_id=35, created_at=datetime.datetime(2023, 6, 27, 15, 35, 4, tzinfo=tzutc()), updated_at=datetime.datetime(2023, 6, 27, 15, 35, 18, tzinfo=tzutc()), deleted_at=None, type=<GetProjectPagesResponse200DataProjectType.SITEMAP: 'SITEMAP'>, is_shared=0, shareable_slug=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, shareable_link=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, embed_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, live_chat_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, additional_properties={}), pages=GetProjectPagesResponse200DataPages(current_page=3, data=[], first_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', from_=None, last_page=1, last_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', links=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, next_page_url=None, path='https://dev.customgpt.ai/api/v1/projects/582/pages', per_page=20, prev_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=2&duration=90&order=desc', to=None, total=10, additional_properties={}), additional_properties={}), additional_properties={}))
# Response(status_code=<HTTPStatus.OK: 200>, content=b'{"data":{"project":{"id":582,"project_name":"Example ChatBot using Sitemap","sitemap_path":null,"user_id":35,"is_chat_active":1,"created_at":"2023-06-27T15:35:04.000000Z","updated_at":"2023-06-27T15:35:18.000000Z","is_shared":0,"deleted_at":null,"type":"SITEMAP"},"pages":{"current_page":4,"data":[],"first_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","from":null,"last_page":1,"last_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","next_page_url":null,"path":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages","per_page":20,"prev_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=3&duration=90&order=desc","to":null,"total":10}},"status":"success"}', headers=Headers({'server': 'nginx', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'vary': 'Accept-Encoding', 'cache-control': 'no-cache, private', 'date': 'Tue, 27 Jun 2023 15:42:51 GMT', 'x-ratelimit-limit': '60', 'x-ratelimit-remaining': '54', 'access-control-allow-origin': '*', 'x-xss-protection': '1; mode=block', 'x-content-type-options': 'nosniff', 'content-encoding': 'gzip'}), parsed=GetProjectPagesResponse200(status=<GetProjectPagesResponse200Status.SUCCESS: 'success'>, data=GetProjectPagesResponse200Data(project=GetProjectPagesResponse200DataProject(id=582, project_name='Example ChatBot using Sitemap', sitemap_path=None, is_chat_active=1, user_id=35, created_at=datetime.datetime(2023, 6, 27, 15, 35, 4, tzinfo=tzutc()), updated_at=datetime.datetime(2023, 6, 27, 15, 35, 18, tzinfo=tzutc()), deleted_at=None, type=<GetProjectPagesResponse200DataProjectType.SITEMAP: 'SITEMAP'>, is_shared=0, shareable_slug=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, shareable_link=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, embed_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, live_chat_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, additional_properties={}), pages=GetProjectPagesResponse200DataPages(current_page=4, data=[], first_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', from_=None, last_page=1, last_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', links=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, next_page_url=None, path='https://dev.customgpt.ai/api/v1/projects/582/pages', per_page=20, prev_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=3&duration=90&order=desc', to=None, total=10, additional_properties={}), additional_properties={}), additional_properties={}))
# Response(status_code=<HTTPStatus.OK: 200>, content=b'{"data":{"project":{"id":582,"project_name":"Example ChatBot using Sitemap","sitemap_path":null,"user_id":35,"is_chat_active":1,"created_at":"2023-06-27T15:35:04.000000Z","updated_at":"2023-06-27T15:35:18.000000Z","is_shared":0,"deleted_at":null,"type":"SITEMAP"},"pages":{"current_page":5,"data":[],"first_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","from":null,"last_page":1,"last_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","next_page_url":null,"path":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages","per_page":20,"prev_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=4&duration=90&order=desc","to":null,"total":10}},"status":"success"}', headers=Headers({'server': 'nginx', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'vary': 'Accept-Encoding', 'cache-control': 'no-cache, private', 'date': 'Tue, 27 Jun 2023 15:42:51 GMT', 'x-ratelimit-limit': '60', 'x-ratelimit-remaining': '53', 'access-control-allow-origin': '*', 'x-xss-protection': '1; mode=block', 'x-content-type-options': 'nosniff', 'content-encoding': 'gzip'}), parsed=GetProjectPagesResponse200(status=<GetProjectPagesResponse200Status.SUCCESS: 'success'>, data=GetProjectPagesResponse200Data(project=GetProjectPagesResponse200DataProject(id=582, project_name='Example ChatBot using Sitemap', sitemap_path=None, is_chat_active=1, user_id=35, created_at=datetime.datetime(2023, 6, 27, 15, 35, 4, tzinfo=tzutc()), updated_at=datetime.datetime(2023, 6, 27, 15, 35, 18, tzinfo=tzutc()), deleted_at=None, type=<GetProjectPagesResponse200DataProjectType.SITEMAP: 'SITEMAP'>, is_shared=0, shareable_slug=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, shareable_link=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, embed_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, live_chat_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, additional_properties={}), pages=GetProjectPagesResponse200DataPages(current_page=5, data=[], first_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', from_=None, last_page=1, last_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', links=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, next_page_url=None, path='https://dev.customgpt.ai/api/v1/projects/582/pages', per_page=20, prev_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=4&duration=90&order=desc', to=None, total=10, additional_properties={}), additional_properties={}), additional_properties={}))
# Response(status_code=<HTTPStatus.OK: 200>, content=b'{"data":{"project":{"id":582,"project_name":"Example ChatBot using Sitemap","sitemap_path":null,"user_id":35,"is_chat_active":1,"created_at":"2023-06-27T15:35:04.000000Z","updated_at":"2023-06-27T15:35:18.000000Z","is_shared":0,"deleted_at":null,"type":"SITEMAP"},"pages":{"current_page":6,"data":[],"first_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","from":null,"last_page":1,"last_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","next_page_url":null,"path":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages","per_page":20,"prev_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=5&duration=90&order=desc","to":null,"total":10}},"status":"success"}', headers=Headers({'server': 'nginx', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'vary': 'Accept-Encoding', 'cache-control': 'no-cache, private', 'date': 'Tue, 27 Jun 2023 15:42:51 GMT', 'x-ratelimit-limit': '60', 'x-ratelimit-remaining': '52', 'access-control-allow-origin': '*', 'x-xss-protection': '1; mode=block', 'x-content-type-options': 'nosniff', 'content-encoding': 'gzip'}), parsed=GetProjectPagesResponse200(status=<GetProjectPagesResponse200Status.SUCCESS: 'success'>, data=GetProjectPagesResponse200Data(project=GetProjectPagesResponse200DataProject(id=582, project_name='Example ChatBot using Sitemap', sitemap_path=None, is_chat_active=1, user_id=35, created_at=datetime.datetime(2023, 6, 27, 15, 35, 4, tzinfo=tzutc()), updated_at=datetime.datetime(2023, 6, 27, 15, 35, 18, tzinfo=tzutc()), deleted_at=None, type=<GetProjectPagesResponse200DataProjectType.SITEMAP: 'SITEMAP'>, is_shared=0, shareable_slug=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, shareable_link=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, embed_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, live_chat_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, additional_properties={}), pages=GetProjectPagesResponse200DataPages(current_page=6, data=[], first_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', from_=None, last_page=1, last_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', links=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, next_page_url=None, path='https://dev.customgpt.ai/api/v1/projects/582/pages', per_page=20, prev_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=5&duration=90&order=desc', to=None, total=10, additional_properties={}), additional_properties={}), additional_properties={}))
# Response(status_code=<HTTPStatus.OK: 200>, content=b'{"data":{"project":{"id":582,"project_name":"Example ChatBot using Sitemap","sitemap_path":null,"user_id":35,"is_chat_active":1,"created_at":"2023-06-27T15:35:04.000000Z","updated_at":"2023-06-27T15:35:18.000000Z","is_shared":0,"deleted_at":null,"type":"SITEMAP"},"pages":{"current_page":7,"data":[],"first_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","from":null,"last_page":1,"last_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","next_page_url":null,"path":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages","per_page":20,"prev_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=6&duration=90&order=desc","to":null,"total":10}},"status":"success"}', headers=Headers({'server': 'nginx', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'vary': 'Accept-Encoding', 'cache-control': 'no-cache, private', 'date': 'Tue, 27 Jun 2023 15:42:52 GMT', 'x-ratelimit-limit': '60', 'x-ratelimit-remaining': '51', 'access-control-allow-origin': '*', 'x-xss-protection': '1; mode=block', 'x-content-type-options': 'nosniff', 'content-encoding': 'gzip'}), parsed=GetProjectPagesResponse200(status=<GetProjectPagesResponse200Status.SUCCESS: 'success'>, data=GetProjectPagesResponse200Data(project=GetProjectPagesResponse200DataProject(id=582, project_name='Example ChatBot using Sitemap', sitemap_path=None, is_chat_active=1, user_id=35, created_at=datetime.datetime(2023, 6, 27, 15, 35, 4, tzinfo=tzutc()), updated_at=datetime.datetime(2023, 6, 27, 15, 35, 18, tzinfo=tzutc()), deleted_at=None, type=<GetProjectPagesResponse200DataProjectType.SITEMAP: 'SITEMAP'>, is_shared=0, shareable_slug=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, shareable_link=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, embed_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, live_chat_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, additional_properties={}), pages=GetProjectPagesResponse200DataPages(current_page=7, data=[], first_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', from_=None, last_page=1, last_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', links=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, next_page_url=None, path='https://dev.customgpt.ai/api/v1/projects/582/pages', per_page=20, prev_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=6&duration=90&order=desc', to=None, total=10, additional_properties={}), additional_properties={}), additional_properties={}))
# Response(status_code=<HTTPStatus.OK: 200>, content=b'{"data":{"project":{"id":582,"project_name":"Example ChatBot using Sitemap","sitemap_path":null,"user_id":35,"is_chat_active":1,"created_at":"2023-06-27T15:35:04.000000Z","updated_at":"2023-06-27T15:35:18.000000Z","is_shared":0,"deleted_at":null,"type":"SITEMAP"},"pages":{"current_page":8,"data":[],"first_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","from":null,"last_page":1,"last_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","next_page_url":null,"path":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages","per_page":20,"prev_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=7&duration=90&order=desc","to":null,"total":10}},"status":"success"}', headers=Headers({'server': 'nginx', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'vary': 'Accept-Encoding', 'cache-control': 'no-cache, private', 'date': 'Tue, 27 Jun 2023 15:42:52 GMT', 'x-ratelimit-limit': '60', 'x-ratelimit-remaining': '50', 'access-control-allow-origin': '*', 'x-xss-protection': '1; mode=block', 'x-content-type-options': 'nosniff', 'content-encoding': 'gzip'}), parsed=GetProjectPagesResponse200(status=<GetProjectPagesResponse200Status.SUCCESS: 'success'>, data=GetProjectPagesResponse200Data(project=GetProjectPagesResponse200DataProject(id=582, project_name='Example ChatBot using Sitemap', sitemap_path=None, is_chat_active=1, user_id=35, created_at=datetime.datetime(2023, 6, 27, 15, 35, 4, tzinfo=tzutc()), updated_at=datetime.datetime(2023, 6, 27, 15, 35, 18, tzinfo=tzutc()), deleted_at=None, type=<GetProjectPagesResponse200DataProjectType.SITEMAP: 'SITEMAP'>, is_shared=0, shareable_slug=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, shareable_link=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, embed_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, live_chat_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, additional_properties={}), pages=GetProjectPagesResponse200DataPages(current_page=8, data=[], first_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', from_=None, last_page=1, last_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', links=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, next_page_url=None, path='https://dev.customgpt.ai/api/v1/projects/582/pages', per_page=20, prev_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=7&duration=90&order=desc', to=None, total=10, additional_properties={}), additional_properties={}), additional_properties={}))
# Response(status_code=<HTTPStatus.OK: 200>, content=b'{"data":{"project":{"id":582,"project_name":"Example ChatBot using Sitemap","sitemap_path":null,"user_id":35,"is_chat_active":1,"created_at":"2023-06-27T15:35:04.000000Z","updated_at":"2023-06-27T15:35:18.000000Z","is_shared":0,"deleted_at":null,"type":"SITEMAP"},"pages":{"current_page":9,"data":[],"first_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","from":null,"last_page":1,"last_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","next_page_url":null,"path":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages","per_page":20,"prev_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=8&duration=90&order=desc","to":null,"total":10}},"status":"success"}', headers=Headers({'server': 'nginx', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'vary': 'Accept-Encoding', 'cache-control': 'no-cache, private', 'date': 'Tue, 27 Jun 2023 15:42:52 GMT', 'x-ratelimit-limit': '60', 'x-ratelimit-remaining': '49', 'access-control-allow-origin': '*', 'x-xss-protection': '1; mode=block', 'x-content-type-options': 'nosniff', 'content-encoding': 'gzip'}), parsed=GetProjectPagesResponse200(status=<GetProjectPagesResponse200Status.SUCCESS: 'success'>, data=GetProjectPagesResponse200Data(project=GetProjectPagesResponse200DataProject(id=582, project_name='Example ChatBot using Sitemap', sitemap_path=None, is_chat_active=1, user_id=35, created_at=datetime.datetime(2023, 6, 27, 15, 35, 4, tzinfo=tzutc()), updated_at=datetime.datetime(2023, 6, 27, 15, 35, 18, tzinfo=tzutc()), deleted_at=None, type=<GetProjectPagesResponse200DataProjectType.SITEMAP: 'SITEMAP'>, is_shared=0, shareable_slug=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, shareable_link=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, embed_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, live_chat_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, additional_properties={}), pages=GetProjectPagesResponse200DataPages(current_page=9, data=[], first_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', from_=None, last_page=1, last_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', links=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, next_page_url=None, path='https://dev.customgpt.ai/api/v1/projects/582/pages', per_page=20, prev_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=8&duration=90&order=desc', to=None, total=10, additional_properties={}), additional_properties={}), additional_properties={}))
# Response(status_code=<HTTPStatus.OK: 200>, content=b'{"data":{"project":{"id":582,"project_name":"Example ChatBot using Sitemap","sitemap_path":null,"user_id":35,"is_chat_active":1,"created_at":"2023-06-27T15:35:04.000000Z","updated_at":"2023-06-27T15:35:18.000000Z","is_shared":0,"deleted_at":null,"type":"SITEMAP"},"pages":{"current_page":10,"data":[],"first_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","from":null,"last_page":1,"last_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=1&duration=90&order=desc","next_page_url":null,"path":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages","per_page":20,"prev_page_url":"https:\\/\\/dev.customgpt.ai\\/api\\/v1\\/projects\\/582\\/pages?page=9&duration=90&order=desc","to":null,"total":10}},"status":"success"}', headers=Headers({'server': 'nginx', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'vary': 'Accept-Encoding', 'cache-control': 'no-cache, private', 'date': 'Tue, 27 Jun 2023 15:42:52 GMT', 'x-ratelimit-limit': '60', 'x-ratelimit-remaining': '48', 'access-control-allow-origin': '*', 'x-xss-protection': '1; mode=block', 'x-content-type-options': 'nosniff', 'content-encoding': 'gzip'}), parsed=GetProjectPagesResponse200(status=<GetProjectPagesResponse200Status.SUCCESS: 'success'>, data=GetProjectPagesResponse200Data(project=GetProjectPagesResponse200DataProject(id=582, project_name='Example ChatBot using Sitemap', sitemap_path=None, is_chat_active=1, user_id=35, created_at=datetime.datetime(2023, 6, 27, 15, 35, 4, tzinfo=tzutc()), updated_at=datetime.datetime(2023, 6, 27, 15, 35, 18, tzinfo=tzutc()), deleted_at=None, type=<GetProjectPagesResponse200DataProjectType.SITEMAP: 'SITEMAP'>, is_shared=0, shareable_slug=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, shareable_link=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, embed_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, live_chat_code=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, additional_properties={}), pages=GetProjectPagesResponse200DataPages(current_page=10, data=[], first_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', from_=None, last_page=1, last_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=1&duration=90&order=desc', links=<customgpt_client.types.Unset object at 0x7f5c44f6a740>, next_page_url=None, path='https://dev.customgpt.ai/api/v1/projects/582/pages', per_page=20, prev_page_url='https://dev.customgpt.ai/api/v1/projects/582/pages?page=9&duration=90&order=desc', to=None, total=10, additional_properties={}), additional_properties={}), additional_properties={}))
